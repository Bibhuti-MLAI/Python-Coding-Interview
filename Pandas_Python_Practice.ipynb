# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibhuti-MLAI/Python-Coding-Interview/blob/main/Pandas_Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas

# %%
import pandas as pd
import numpy as np

# %%
df_orders =pd.read_csv("/content/drive/MyDrive/Krish playlist practice/orders.csv")
df =pd.read_csv("/content/drive/MyDrive/Krish playlist practice/orders.csv")

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
#        'region', 'product_id', 'category', 'sales', 'quantity', 'profit',
#        'category_len', 'profit_loss', 'order_year'],
#       dtype='object')

# %%
df_returns = pd.read_csv("/content/drive/MyDrive/Krish playlist practice/returns.csv")

# %%
df_new= df[['order_id', 'order_date', 'ship_date']]
df_new
# Out:
#           order_id  order_date   ship_date
# 0   CA-2020-152156  08-11-2020  11-11-2020
# 1   CA-2020-152156  08-11-2020  11-11-2020
# 2   CA-2020-138688  12-06-2020  16-06-2020
# 3   US-2019-108966  11-10-2019  18-10-2019
# 4   US-2019-108966  11-10-2019  18-10-2019
# 5   CA-2018-115812  09-06-2018  14-06-2018
# 6   CA-2018-115812  09-06-2018  14-06-2018
# 7   CA-2018-115812  09-06-2018  14-06-2018
# 8   CA-2018-115812  09-06-2018  14-06-2018
# 9   CA-2018-115812  09-06-2018  14-06-2018
# 10  CA-2018-115812  09-06-2018  14-06-2018
# 11  CA-2018-115812  09-06-2018  14-06-2018
# 12  CA-2021-114412  15-04-2021  20-04-2021
# 13  CA-2020-161389  05-12-2020  10-12-2020
# 14  US-2019-118983  22-11-2019  26-11-2019
# 15  US-2019-118983  22-11-2019  26-11-2019
# 16  CA-2018-105893  11-11-2018  18-11-2018
# 17  CA-2018-167164  13-05-2018  15-05-2018
# 18  CA-2018-143336  27-08-2018  01-09-2018
# 19  CA-2018-143336  27-08-2018  01-09-2018
# 20  CA-2018-143336  27-08-2018  01-09-2018
# ...

# %%
df_returns
# Out:
#          order_id return_reason
# 0  CA-2018-105893   bad quality
# 1  CA-2018-143336    wrong item
# 2  CA-2018-146703    wrong item
# 3  CA-2018-167164         other
# 4  CA-2019-106320   bad quality
# 5  CA-2019-115742         other
# 6  CA-2020-101343   bad quality
# 7  CA-2020-117590    wrong item

# %%
df['order_date']
# Out:
# 0     08-11-2020
# 1     08-11-2020
# 2     12-06-2020
# 3     11-10-2019
# 4     11-10-2019
# 5     09-06-2018
# 6     09-06-2018
# 7     09-06-2018
# 8     09-06-2018
# 9     09-06-2018
# 10    09-06-2018
# 11    09-06-2018
# 12    15-04-2021
# 13    05-12-2020
# 14    22-11-2019
# 15    22-11-2019
# 16    11-11-2018
# 17    13-05-2018
# 18    27-08-2018
# 19    27-08-2018
# 20    27-08-2018
# 21    09-12-2020
# 22    09-12-2020
# 23    16-07-2021
# 24    25-09-2019
# 25    16-01-2020
# 26    16-01-2020
# 27    17-09-2019
# 28    17-09-2019
# 29    17-09-2019
# 30    17-09-2019
# 31    17-09-2019
# 32    17-09-2019
# 33    17-09-2019
# 34    19-10-2021
# 35    08-12-2020
# 36    08-12-2020
# 37    27-12-2019
# 38    27-12-2019
# 39    27-12-2019
# 40    27-12-2019
# 41    10-09-2021
# 42    17-07-2020
# 43    19-09-2021
# 44    11-03-2020
# 45    11-03-2020
# 46    20-10-2018
# 47    20-06-2020
# 48    20-06-2020
# 49    18-04-2019
# Name: order_date, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0:10]
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 2  CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045   West
# 3  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 5  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 6  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 7  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 8  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
# 9  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710   West
#
#         product_id         category  sales  quantity  profit
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9
# ...

# %%
df.set_index('order_id' ,inplace=True)

# %%
df
# Out:
#                 order_date   ship_date       ship_mode customer_id   region  \
# order_id
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520    South
# CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045     West
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335    South
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710     West
# ...

# %%
df.reset_index(inplace=True)

# %%
df.sort_index(ascending=True)
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.loc[df['region']=='South']
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 12  CA-2021-114412  15-04-2021  20-04-2021  Standard Class    AA-10480  South
# 43  CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
#
#          product_id         category  sales  quantity  profit
# 0   FUR-BO-10001798        Furniture  262.0         2    41.9
# 1   FUR-CH-10000454        Furniture  731.9         3   219.6
# 3   FUR-TA-10000577        Furniture  957.6         5  -383.0
# 4   OFF-ST-10000760  Office Supplies   22.4         2     2.5
# 12  OFF-PA-10002365  Office Supplies   15.6         3     5.4
# ...

# %%
df['category_len']=df['category'].apply(len)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
def profit_loss(profit):
  if profit > 0:
    return "profit"
  else:
    return "loss"
df['profit_loss']=df['profit'].apply(profit_loss)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.describe()
# Out:
#              sales   quantity       profit  category_len
# count    50.000000  50.000000    50.000000     50.000000
# mean    300.792000   3.920000   -20.550000     12.560000
# std     547.564035   1.977836   251.767027      2.800583
# min       2.500000   2.000000 -1665.100000      9.000000
# 25%      20.075000   2.000000     2.500000     10.000000
# 50%      74.650000   3.000000     8.350000     15.000000
# 75%     249.875000   5.000000    17.650000     15.000000
# max    3083.400000   9.000000   240.300000     15.000000

# %%
df.isnull()
# Out:
#     order_id  order_date  ship_date  ship_mode  customer_id  region  \
# 0      False       False      False      False        False   False
# 1      False       False      False      False        False   False
# 2      False       False      False      False        False   False
# 3      False       False      False      False        False   False
# 4      False       False      False      False        False   False
# 5      False       False      False      False        False   False
# 6      False       False      False      False        False   False
# 7      False       False      False      False        False   False
# 8      False       False      False      False        False   False
# 9      False       False      False      False        False   False
# 10     False       False      False      False        False   False
# 11     False       False      False      False        False   False
# 12     False       False      False      False        False   False
# ...

# %%
df.isnull().sum()
# Out:
# order_id        0
# order_date      0
# ship_date       0
# ship_mode       0
# customer_id     0
# region          0
# product_id      0
# category        0
# sales           0
# quantity        0
# profit          0
# category_len    0
# profit_loss     0
# dtype: int64

# %%
df.dropna()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.dtypes
# Out:
# order_id         object
# order_date       object
# ship_date        object
# ship_mode        object
# customer_id      object
# region           object
# product_id       object
# category         object
# sales           float64
# quantity          int64
# profit          float64
# category_len      int64
# profit_loss      object
# dtype: object

# %%
df['order_date']=pd.to_datetime(df['order_date'],format='%d-%m-%Y')

# %%
df['ship_date']=pd.to_datetime(df['ship_date'],format='%d-%m-%Y')

# %%
df.head()
# Out:
#          order_id order_date  ship_date       ship_mode customer_id region  \
# 0  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520  South
# 1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520  South
# 2  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045   West
# 3  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335  South
# 4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335  South
#
#         product_id         category  sales  quantity  profit  category_len  \
# 0  FUR-BO-10001798        Furniture  262.0         2    41.9             9
# 1  FUR-CH-10000454        Furniture  731.9         3   219.6             9
# 2  OFF-LA-10000240  Office Supplies   14.6         2     6.9            15
# 3  FUR-TA-10000577        Furniture  957.6         5  -383.0             9
# 4  OFF-ST-10000760  Office Supplies   22.4         2     2.5            15
#
#   profit_loss
# 0      profit
# 1      profit
# 2      profit
# ...

# %%
df['order_year']=df['order_date'].dt.year

# %%
df
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 0   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 1   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 2   CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045     West
# 3   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 4   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 5   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 6   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 7   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 8   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 9   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# ...

# %%
df['sales'].sum()
# Out:
# np.float64(15039.599999999999)

# %%
df.groupby('region')['sales'].sum()
# Out:
# region
# Central    3824.8
# East       3467.7
# South      2085.1
# West       5662.0
# Name: sales, dtype: float64

# %%
df.groupby('region')['sales'].agg(["min","max","sum"])
# Out:
#           min     max     sum
# region
# Central   2.5  1097.5  3824.8
# East      3.3  3083.4  3467.7
# South    15.6   957.6  2085.1
# West      7.3  1706.2  5662.0

# %%
df.groupby('category').agg({'sales':'sum','profit':'mean'})
# Out:
#                   sales      profit
# category
# Furniture        8965.6 -136.866667
# Office Supplies  2222.6    7.685714
# Technology       3851.4   39.970000

# %%
df["category"].value_counts()
# Out:
# category
# Office Supplies    28
# Furniture          12
# Technology         10
# Name: count, dtype: int64

# %%
pd.pivot_table(df,index="region",columns="category",values="sales",aggfunc="sum",fill_value=0)
# Out:
# category  Furniture  Office Supplies  Technology
# region
# Central       935.4           1227.5      1661.9
# East         3279.0            121.9        66.8
# South        1951.5            133.6         0.0
# West         2799.7            739.6      2122.7

# %%
df_returns
# Out:
#   return_order_id return_reason
# 0  CA-2018-105893   bad quality
# 1  CA-2018-143336    wrong item
# 2  CA-2018-146703    wrong item
# 3  CA-2018-167164         other
# 4  CA-2019-106320   bad quality
# 5  CA-2019-115742         other
# 6  CA-2020-101343   bad quality
# 7  CA-2020-117590    wrong item

# %%
df=pd.merge(left= df_orders,right=df_returns,on='order_id',how="left")

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.groupby("return_reason")["sales"].sum()
# Out:
# return_reason
# bad quality    1788.4
# other            93.7
# wrong item     1745.2
# Name: sales, dtype: float64
