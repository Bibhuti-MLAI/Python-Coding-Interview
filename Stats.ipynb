# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibhuti-MLAI/Python-Coding-Interview/blob/main/Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/PES Univeristy/SMDM/tip.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.skew(numeric_only=True)
# Out:
# total_bill    1.133213
# tip           1.465451
# size          1.447882
# dtype: float64

# %%
df.kurtosis(numeric_only=True)
# Out:
# total_bill    1.218484
# tip           3.648376
# size          1.731700
# dtype: float64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'total_bill'}>,
#         <Axes: title={'center': 'tip'}>],
#        [<Axes: title={'center': 'size'}>, <Axes: >]], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['total_bill'], df['tip'], alpha=0.5)
plt.title('Scatter plot of Profit with Marketing Spend')
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %%
covariance = df['total_bill'].cov(df['tip'])
print(f"Covariance between total_bill and tip: {covariance}")
# Out:
# Covariance between total_bill and tip: 8.323501629224854

# %%
cov_matrix = df.cov(numeric_only=True)
print("Pearson cov Matrix:")
print(cov_matrix)
# Out:
# Pearson cov Matrix:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
correlation_matrix = df.corr(numeric_only=True)
print("Pearson Correlation Matrix:")
print(correlation_matrix)
# Out:
# Pearson Correlation Matrix:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
