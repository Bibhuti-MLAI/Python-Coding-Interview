# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibhuti-MLAI/Python-Coding-Interview/blob/main/Pyhton_Coding_interview_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Finding the commen letters in two string
def common_letters():
  str1 = input("first string: ")
  str2 = input("second string: ")
  s1= set(str1)
  s2= set(str2)
  lst = s1&s2
  print(lst)

common_letters()
# Out:
# first string: Bibhuti
# second string: Bhusan
# {'B', 'u', 'h'}

# %%
#count the frequency of words in a string
def count_words():
  str = input("input the string: ")
  li = str.split()
  d = {}
  for i in li:
    if i not in d.keys():
      d[i] = 0
    d[i] = d[i]+1
  print(d)
count_words()
# Out:
# input the string: Bibhuti BHusan Bibhuti Bhusan Sahu
# {'Bibhuti': 2, 'BHusan': 1, 'Bhusan': 1, 'Sahu': 1}

# %%
import collections

def find_common_letters():
  """
  Finds and prints the common letters between two input strings.
  It converts strings to sets to easily find the intersection of characters.
  """
  # Prompt the user for the first string
  string1 = input("Enter the first string: ")
  # Prompt the user for the second string
  string2 = input("Enter the second string: ")

  # Convert strings to sets of characters for efficient intersection
  set1 = set(string1)
  set2 = set(string2)

  # Find the intersection of the two sets to get common letters
  common_chars = set1.intersection(set2) # Using .intersection() for clarity over &

  # Print the set of common letters
  print("Common letters:", common_chars)


def count_word_frequencies():
  """
  Counts and prints the frequency of each word in an input string.
  Uses collections.Counter for an efficient and Pythonic solution.
  """
  # Prompt the user for the input string
  input_string = input("Enter the string to count words: ")

  # Split the string into a list of words
  # .split() without arguments splits by whitespace and handles multiple spaces
  words = input_string.split()

  # Use collections.Counter to count word frequencies
  # Counter is a dict subclass for counting hashable objects
  word_counts = collections.Counter(words)

  # Print the dictionary of word frequencies
  print("Word frequencies:", word_counts)

# To run these functions, uncomment the respective calls below:
find_common_letters()
count_word_frequencies()
# Out:
# Enter the first string: Bibhuti
# Enter the second string: Bhusan
# Common letters: {'B', 'u', 'h'}
# Enter the string to count words: Bibhuti Bhusan Bibhuti Bhusan Sahu
# Word frequencies: Counter({'Bibhuti': 2, 'Bhusan': 2, 'Sahu': 1})

# %%
#finding the missing number
def finding_missing_number():
  n=a[-1] # This assumes n is the last element of the list 'a'.
          # For a missing number problem, 'n' usually represents the expected maximum value in the sequence.
  # sum1=0 # This line is redundant as sum1 is immediately reassigned.
  total = n*(n+1)//2 # Calculates the sum of numbers from 1 to n
  sum1 = sum(a)      # Calculates the sum of the elements in list 'a'
  print(total-sum1)  # Corrected: subtract sum1 (the variable) instead of sum (the built-in function)
a = [1,2,3,4,6,7] # Currently, no number is missing in this list.
finding_missing_number()
# Out:
# 5

# %%
#list to dictionary
def list_to_dict():
  key = [1,2,3]
  values = ["Math","Physics","Chemestry"]
  d = dict(zip(key,values))
  print(d)
list_to_dict()
# Out:
# {1: 'Math', 2: 'Physics', 3: 'Chemestry'}

# %% [markdown]
# Input:
# google.com
#
# Output:
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}
#
# Explanation:
# In the string "google.com", ‘g’ appears 2 times, ‘o’ 3 times, ‘l’ 1 time, ‘e’ 1 time, ‘.’ 1 time, ‘c’ 1 time, and ‘m’ 1 time.

# %%
input_string = input("please enter the string: ")
char_frequency = {}

for i in input_string.lower():
  char_frequency[i] = char_frequency.get(i , 0) +1
print(char_frequency)
# Out:
# please enter the string: Bibhuti
# {'b': 2, 'i': 2, 'h': 1, 'u': 1, 't': 1}

# %%
string = input("Please enter the string : ")
print("What operation you want 1. Total length of the string  or 2. count the characters of the string ")
choice = int(input())
if choice ==1:
  print(len(string))
elif choice == 2:
  char = input("enter the character: ")
  if char in string:
    print(string.count(char))
  else:
    print("character not found")
else:
  print("Invelid Choice")
# Out:
# Please enter the string : Bibhuti Bhusan
# What operation you want 1. Total length of the string  or 2. count the characters of the string
# 2
# enter the character: B
# 2

# %%
def common_letters():
  str1 = input("enter the first string ")
  str2 = input("enter the second string ")
  # Convert strings to sets to find common characters
  set1 = set(str1)
  set2 = set(str2)
  lst = set1 & set2 # Use & operator on sets
  print(lst)

common_letters()
# Out:
# enter the first string Bibhuti
# enter the second string Bhusan
# {'u', 'B', 'h'}

# %%
#counting the frequency of words
def count_frequency():
  string = input("enter the string: ")
  li = string.split()
  d = {}
  for i in li:
    if i not in d.keys():
      d[i] = 0
      d[i] = d[i]+1
  print(d)

count_frequency()
# Out:
# enter the string: Bibhuti
# {'Bibhuti': 1}

# %%
def list_to_dict():
    key = [1,2,3,4]
    values = ["Math","Phy","Bio","Chem"]
    d = dict(zip(key,values))
    print(d)

list_to_dict()
# Out:
# {1: 'Math', 2: 'Phy', 3: 'Bio', 4: 'Chem'}

# %%
import collections

# Python Interview Question: Find the first non-repeated character in a string.
# For example, if the input is "teeter", the output should be 'r'.
# If all characters repeat, or the string is empty, return None.

def find_first_non_repeated_char(s):
    if not s:
        return None

    # Use collections.Counter to get character frequencies
    char_counts = collections.Counter(s)

    # Iterate through the string to find the first character with a count of 1
    for char in s:
        if char_counts[char] == 1:
            return char

    # If no non-repeated character is found
    return None

# Test cases
print(f"'teeter': {find_first_non_repeated_char('teeter')}")
print(f"'google': {find_first_non_repeated_char('google')}")
print(f"'aabbcc': {find_first_non_repeated_char('aabbcc')}")
print(f"'a': {find_first_non_repeated_char('a')}")
print(f"'': {find_first_non_repeated_char('')}")
# Out:
# 'teeter': r
# 'google': l
# 'aabbcc': None
# 'a': a
# '': None
